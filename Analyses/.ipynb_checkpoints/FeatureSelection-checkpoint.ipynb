# %%
from sklearn.feature_selection import mutual_info_regression, f_regression
from sklearn.feature_selection import SelectPercentile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import Imputer

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
from subprocess import check_output

# %%
class ReduceVIF(BaseEstimator, TransformerMixin):
    def __init__(self, thresh=5.0, impute=True, impute_strategy='median'):
        # From looking at documentation, values between 5 and 10 are "okay".
        # Above 10 is too high and so should be removed.
        self.thresh = thresh
        
        # The statsmodel function will fail with NaN values, as such we have to impute them.
        # By default we impute using the median value.
        # This imputation could be taken out and added as part of an sklearn Pipeline.
        if impute:
            self.imputer = Imputer(strategy=impute_strategy)

    def fit(self, X, y=None):
        print('ReduceVIF fit')
        if hasattr(self, 'imputer'):
            self.imputer.fit(X)
        return self

    def transform(self, X, y=None):
        print('ReduceVIF transform')
        columns = X.columns.tolist()
        if hasattr(self, 'imputer'):
            X = pd.DataFrame(self.imputer.transform(X), columns=columns)
        return ReduceVIF.calculate_vif(X, self.thresh)

    @staticmethod
    def calculate_vif(X, thresh=5.0):
        # Taken from https://stats.stackexchange.com/a/253620/53565 and modified
        dropped=True
        while dropped:
            # Loop repeatedly until we find that all columns within our dataset
            # have a VIF value we're happy with.
            variables = X.columns
            dropped=False
            vif = []
            new_vif = 0
            for var in X.columns:
                new_vif = variance_inflation_factor(X[variables].values, X.columns.get_loc(var))
                vif.append(new_vif)
                if np.isinf(new_vif):
                    break
            max_vif = max(vif)
            if max_vif > thresh:
                maxloc = vif.index(max_vif)
                print(f'Dropping {X.columns[maxloc]} with vif={max_vif}')
                X = X.drop([X.columns.tolist()[maxloc]], axis=1)
                dropped=True
        return X
    
transformer = ReduceVIF()

# %%
df = pd.read_csv(r'B:\Phillip\Mapping\BlockGroupJoin\CNTYVARS.csv')
df['HSGRAD_PRCNT'] = df['HSGRAD_CY']/df['TOTPOP_CY']

# %%
dtype_df = df.dtypes.reset_index()
dtype_df.columns = ["Count", "Column Type"]
print(dtype_df[dtype_df['Column Type'] == 'object'])
# Out:
#          Count Column Type
# 783   TSEGCODE      object
# 784   TSEGNAME      object
# 854  TLIFECODE      object
# 855  TLIFENAME      object

# %%
dp = ['OBJECTID','Customers', 'UNITS', 'SALES', 'LOG_UNITS', 'TSEGCODE','TSEGNAME','TLIFECODE','TLIFENAME']

X = df.drop(dp, axis=1)

#X2 = transformer.fit_transform(X, y)

#X2.head()

# %%
y = df[['LOG_UNITS']]
y.shape
# Out:
# (3109, 1)

# %%
selector = SelectPercentile(f_regression, percentile=20)
columns = X.columns
selector.fit_transform(X, np.array(y))
labels = [columns[x] for x in selector.get_support(indices=True) if x]
XNew = pd.DataFrame(selector.fit_transform(X, np.array(y)), columns = labels)

lst = list()
for n, s in zip(columns, selector.scores_):
    lst.append((s, n))

scores = pd.DataFrame(lst, columns=['score','name'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py:279: RuntimeWarning: invalid value encountered in true_divide
#   corr /= row_norms(X.T)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
scores.sort_values(by='score',inplace=True, ascending=False)
scores.reset_index(inplace=True)
scores.to_csv(r'B:\Phillip\Mapping\BlockGroupJoin\varscores.csv')

# %%
XNew.head()
# Out:
#    TOTHH_CY  FAMHH_CY  OWNER_CY  POP45_CY  POP50_CY  POP55_CY  POP60_CY  \
# 0  574249.0  371388.0  296409.0  109727.0  111335.0  106344.0   91368.0
# 1   15386.0   10349.0   11317.0    2555.0    2941.0    3338.0    3567.0
# 2   89802.0   53869.0   50578.0   12123.0   13970.0   15620.0   15327.0
# 3   18933.0   13074.0   14320.0    2762.0    3594.0    4257.0    4409.0
# 4    7392.0    5539.0    4422.0    1351.0    1330.0    1413.0    1249.0
#
#    POP70_CY  POP18UP_CY  POP21UP_CY    ...     DIA45BASCY  DIA65BASCY  \
# 0   50545.0   1250549.0   1181778.0    ...       118012.0     70405.0
# 1    2465.0     32545.0     31341.0    ...         2475.0      3470.0
# 2    9419.0    182596.0    168771.0    ...        13784.0     13779.0
# 3    2983.0     37151.0     35835.0    ...         3291.0      4251.0
# 4     747.0     16097.0     15186.0    ...         1395.0      1039.0
#
#    NWBASE_CY  NWA45BASCY  NWA65BASCY  EDUCBASECY  MARBASE_CY   THHBASE  \
# 0   574228.0    118012.0     70405.0   1091644.0   1307249.0  574249.0
# 1    15386.0      2475.0      3470.0     29975.0     33779.0   15386.0
# 2    89802.0     13784.0     13779.0    150663.0    190722.0   89802.0
# 3    18933.0      3291.0      4251.0     34240.0     38806.0   18933.0
# 4     7392.0      1395.0      1039.0     14058.0     17105.0    7392.0
#
#    TADULTBASE      HH_C
# 0   1250549.0  545138.0
# 1     32545.0   14569.0
# 2    182596.0   87618.0
# 3     37151.0   18886.0
# 4     16097.0    7056.0
#
# [5 rows x 117 columns]

# %%
X2 = transformer.fit_transform(XNew)

X2.head()
# Out:
# ReduceVIF fit
# ReduceVIF transform
# Dropping TOTHH_CY with vif=inf
# Dropping POP45_CY with vif=inf
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:167: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Dropping POP50_CY with vif=inf
# Dropping POP60_CY with vif=inf
# Dropping POP70_CY with vif=inf
# Dropping POP18UP_CY with vif=inf
# Dropping MALE50_CY with vif=inf
# Dropping MALE60_CY with vif=inf
# Dropping FEM40_CY with vif=inf
# Dropping FEM45_CY with vif=inf
# Dropping FEM50_CY with vif=inf
# Dropping FEM55_CY with vif=inf
# Dropping FEM60_CY with vif=inf
# Dropping FEM65_CY with vif=inf
# Dropping FEM70_CY with vif=inf
# Dropping AGE46_CY with vif=inf
# Dropping AGE47_CY with vif=inf
# Dropping AGE48_CY with vif=inf
# Dropping AGE59_CY with vif=inf
# Dropping AGE60_CY with vif=inf
# Dropping AGE61_CY with vif=inf
# Dropping AGE62_CY with vif=inf
# Dropping AGE63_CY with vif=inf
# Dropping AGE69_CY with vif=inf
# Dropping AGE70_CY with vif=inf
# Dropping AGE71_CY with vif=inf
# Dropping AGE72_CY with vif=inf
# Dropping HINCBASECY with vif=inf
# Dropping IA45BASECY with vif=inf
# Dropping IA65BASECY with vif=inf
# Dropping DIBASE_CY with vif=inf
# Dropping DIA45BASCY with vif=inf
# Dropping DIA65BASCY with vif=inf
# Dropping THHBASE with vif=5036715853.611901
# Dropping OWNER_CY with vif=36250542.60308222
# Dropping POP55_CY with vif=14645538.913131157
# Dropping MALE70_CY with vif=2956018.505796154
# Dropping POP21UP_CY with vif=2463942.0803492847
# Dropping AGE51_CY with vif=2198041.495702916
# Dropping AGE50_CY with vif=1838430.5119724898
# Dropping AGE64_CY with vif=1720007.6334226546
# Dropping AGE45_CY with vif=1648527.8180470983
# Dropping AGE54_CY with vif=1619592.3540947135
# Dropping AGE55_CY with vif=1501936.8416538176
# Dropping AGE53_CY with vif=1351443.7737046087
# Dropping AGE49_CY with vif=1209417.390631013
# Dropping AGE68_CY with vif=1063672.744200701
# Dropping AGE58_CY with vif=918868.0320324547
# Dropping FEM21UP_CY with vif=668960.6567762656
# Dropping AGE73_CY with vif=651636.02085886
# Dropping FAGE46_CY with vif=647286.7263799715
# Dropping AGE65_CY with vif=637628.1763732826
# Dropping FAGE51_CY with vif=636195.4009072413
# Dropping TADULTBASE with vif=551110.6170495264
# Dropping FAGE41_CY with vif=543533.9324617306
# Dropping FAGE58_CY with vif=535233.5065213802
# Dropping FAGE50_CY with vif=522461.1847436509
# Dropping FAGE45_CY with vif=496279.2339749986
# Dropping FAGE64_CY with vif=479730.6015095152
# Dropping MAGE46_CY with vif=474631.1824001471
# Dropping AGE67_CY with vif=453640.1333569218
# Dropping FAGE63_CY with vif=434520.17070103897
# Dropping FAGE48_CY with vif=424297.795531358
# Dropping FAGE59_CY with vif=411858.90107022104
# Dropping FAGE43_CY with vif=400262.69615228695
# Dropping FAGE54_CY with vif=384478.92736959836
# Dropping MAGE48_CY with vif=364876.4183610443
# Dropping FAGE55_CY with vif=363247.9325250923
# Dropping FAGE68_CY with vif=346496.06473707367
# Dropping FAGE53_CY with vif=346136.0599354713
# Dropping FAGE44_CY with vif=323193.29890098143
# Dropping FAGE56_CY with vif=308547.0044981127
# Dropping MAGE61_CY with vif=296801.35271349904
# Dropping FAGE69_CY with vif=285039.3847392609
# Dropping FAGE61_CY with vif=283481.6022152635
# Dropping MAGE63_CY with vif=257239.2034020035
# Dropping FAGE49_CY with vif=247782.60152132137
# Dropping FAGE60_CY with vif=225609.73454515357
# Dropping FAGE66_CY with vif=219030.4668356892
# Dropping MAGE60_CY with vif=180915.41841824973
# Dropping FAGE65_CY with vif=166920.95942241733
# Dropping FAGE71_CY with vif=120255.55476815466
# Dropping MAGE71_CY with vif=103587.3971946315
# Dropping AGE44_CY with vif=84488.98754462831
# Dropping FAGE70_CY with vif=82791.32141415699
# Dropping MAGE73_CY with vif=78748.32816891593
# Dropping FAGE74_CY with vif=73144.28018149214
# Dropping AGE52_CY with vif=66367.65205901692
# Dropping MAGE70_CY with vif=62290.50081707183
# Dropping MARBASE_CY with vif=56437.6274344781
# Dropping FAGE40_CY with vif=42752.017884569046
# Dropping MAGE59_CY with vif=20022.91115307349
# Dropping NWA45BASCY with vif=18610.99621125033
# Dropping FAGE47_CY with vif=15641.038710803885
# Dropping FAGE57_CY with vif=13692.358454156287
# Dropping MAGE69_CY with vif=12875.619750066522
# Dropping EDUCBASECY with vif=10971.87149275744
# Dropping AGE75_CY with vif=10649.67185275627
# Dropping FAGE62_CY with vif=8363.36288698876
# Dropping NWA65BASCY with vif=5707.231290001386
# Dropping HH_C with vif=5043.74044485042
# Dropping IA55UBASCY with vif=3885.6189924082933
# Dropping FAGE67_CY with vif=3344.1974766159774
# Dropping FAMHH_CY with vif=2930.308543815407
# Dropping FEM18UP_CY with vif=1840.3768863796352
# Dropping FAGE72_CY with vif=1174.1452526754686
# Dropping FAGE42_CY with vif=1021.7585754053058
# Dropping FAGE52_CY with vif=692.918687079285
# Dropping MAGE62_CY with vif=430.4524268291939
# Dropping NWBASE_CY with vif=244.48053742590903
# Dropping MARRIED_CY with vif=242.7076645071962
# Dropping VALBASE_CY with vif=56.27838772424782
# Dropping MAGE72_CY with vif=49.16389605628192
# Dropping DIVORCD_CY with vif=36.97736009704349
# Dropping MAGE47_CY with vif=28.82368697941838
# Dropping NONHISP_CY with vif=14.29420348086337
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-30-f24ded12c127> in <module>()
# ----> 1 X2 = transformer.fit_transform(XNew)
#       2
#       3 X2.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     492         if y is None:
#     493             # fit method of arity 1 (unsupervised transformation)
# --> 494             return self.fit(X, **fit_params).transform(X)
#     495         else:
#     496             # fit method of arity 2 (supervised transformation)
#
# <ipython-input-5-c866a374bc6b> in transform(self, X, y)
#      22         if hasattr(self, 'imputer'):
#      23             X = pd.DataFrame(self.imputer.transform(X), columns=columns)
# ---> 24         return ReduceVIF.calculate_vif(X, self.thresh)
#      25
#      26     @staticmethod
#
# <ipython-input-5-c866a374bc6b> in calculate_vif(X, thresh)
#      36             new_vif = 0
#      37             for var in X.columns:
# ---> 38                 new_vif = variance_inflation_factor(X[variables].values, X.columns.get_loc(var))
#      39                 vif.append(new_vif)
#      40                 if np.isinf(new_vif):
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py in variance_inflation_factor(exog, exog_idx)
#     164     mask = np.arange(k_vars) != exog_idx
#     165     x_noti = exog[:, mask]
# --> 166     r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     167     vif = 1. / (1. - r_squared_i)
#     168     return vif
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     629                  **kwargs):
#     630         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 631                                   hasconst=hasconst, **kwargs)
#     632         if "weights" in self._init_keys:
#     633             self._init_keys.remove("weights")
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     524             weights = weights.squeeze()
#     525         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 526                                   weights=weights, hasconst=hasconst, **kwargs)
#     527         nobs = self.exog.shape[0]
#     528         weights = self.weights
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#      93     """
#      94     def __init__(self, endog, exog, **kwargs):
# ---> 95         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#      96         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#      97
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     210
#     211     def __init__(self, endog, exog=None, **kwargs):
# --> 212         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     213         self.initialize()
#     214
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      61         hasconst = kwargs.pop('hasconst', None)
#      62         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 63                                       **kwargs)
#      64         self.k_constant = self.data.k_constant
#      65         self.exog = self.data.exog
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      86
#      87     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 88         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      89         # kwargs arrays could have changed, easier to just attach here
#      90         for key in kwargs:
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     628     klass = handle_data_class_factory(endog, exog)
#     629     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 630                  **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      77
#      78         # this has side-effects, attaches k_constant and const_idx
# ---> 79         self._handle_constant(hasconst)
#      80         self._check_integrity()
#      81         self._cache = resettable_cache()
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     171                             (np.ones(self.exog.shape[0]), self.exog))
#     172                 rank_augm = np_matrix_rank(augmented_exog)
# --> 173                 rank_orig = np_matrix_rank(self.exog)
#     174                 self.k_constant = int(rank_orig == rank_augm)
#     175                 self.const_idx = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in matrix_rank(M, tol)
#    1586     if M.ndim < 2:
#    1587         return int(not all(M==0))
# -> 1588     S = svd(M, compute_uv=False)
#    1589     if tol is None:
#    1590         tol = S.max() * max(M.shape) * finfo(S.dtype).eps
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv)
#    1381     """
#    1382     a, wrap = _makearray(a)
# -> 1383     _assertNoEmpty2d(a)
#    1384     _assertRankAtLeast2(a)
#    1385     t, result_t = _commonType(a)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _assertNoEmpty2d(*arrays)
#     220     for a in arrays:
#     221         if a.size == 0 and product(a.shape[-2:]) == 0:
# --> 222             raise LinAlgError("Arrays cannot be empty")
#     223
#     224
#
# LinAlgError: Arrays cannot be empty

# %%
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()
selector = RFECV(estimator=regression, cv=2, scoring='neg_mean_squared_error')
selector.fit(X, y)
print('Optimal number of features: %d' % selector.n_features_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Optimal number of features: 13

# %%
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(selector.grid_scores_) + 1), selector.grid_scores_)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-b28676caa605> in <module>()
#       2 plt.xlabel("Number of features selected")
#       3 plt.ylabel("Cross validation score (nb of correct classifications)")
# ----> 4 plt.plot(range(1, len(selector.grid_scores_) + 1), selector.grid_scores_)
#       5 plt.show()
#
# AttributeError: 'SelectPercentile' object has no attribute 'grid_scores_'

# %%
lst = list()
for n, s in zip(X.columns, selector.grid_scores_):
    lst.append((s, n))

scores = pd.DataFrame(lst, columns=['score','name'])

# %%
scores.sort_values(by='score',inplace=True, ascending=False)
scores.reset_index(inplace=True)
scores
# Out:
#       index         score        name
# 0        15 -1.238624e+00  FAMGRW10CY
# 1        17 -1.240941e+00     POP5_CY
# 2        18 -1.244718e+00    POP10_CY
# 3        16 -1.248249e+00     POP0_CY
# 4        21 -1.259206e+00    POP25_CY
# 5        19 -1.271689e+00    POP15_CY
# 6        20 -1.272744e+00    POP20_CY
# 7        22 -1.276147e+00    POP30_CY
# 8        14 -1.302547e+00   HHGRW10CY
# 9        12 -1.309250e+00   VACANT_CY
# 10       13 -1.309521e+00  POPGRW10CY
# 11       23 -1.322585e+00    POP35_CY
# 12       25 -1.335920e+00    POP45_CY
# 13       24 -1.386597e+00    POP40_CY
# 14       26 -1.421899e+00    POP50_CY
# 15        7 -1.442899e+00    FAMHH_CY
# 16       28 -1.450098e+00    POP60_CY
# 17       27 -1.483347e+00    POP55_CY
# 18       36 -1.501105e+00   MEDAGE_CY
# 19       34 -1.509022e+00  POP18UP_CY
# 20       35 -1.529115e+00  POP21UP_CY
# 21       11 -1.551548e+00   RENTER_CY
# 22       29 -1.552728e+00    POP65_CY
# 23       33 -1.553443e+00    POP85_CY
# 24       37 -1.571530e+00    MALES_CY
# 25       39 -1.585778e+00    MALE5_CY
# 26       38 -1.585934e+00    MALE0_CY
# 27       10 -1.606330e+00    OWNER_CY
# 28       30 -1.629557e+00    POP70_CY
# 29       40 -1.636244e+00   MALE10_CY
# ...     ...           ...         ...
# 1133    822 -1.419216e+11       THH40
# 1134    821 -1.419218e+11       THH39
# 1135    823 -1.423137e+11       THH41
# 1136    824 -1.423138e+11       THH42
# 1137    825 -1.423222e+11       THH43
# 1138    739 -1.505638e+11  AGGIA45_FY
# 1139    736 -1.524148e+11  AGGIA15_FY
# 1140    737 -1.524177e+11  AGGIA25_FY
# 1141    738 -1.524183e+11  AGGIA35_FY
# 1142    735 -1.532210e+11  AGGIA75_CY
# 1143    734 -1.533240e+11  AGGIA65_CY
# 1144    742 -1.533346e+11  AGGIA75_FY
# 1145    740 -1.533348e+11  AGGIA55_FY
# 1146    741 -1.533352e+11  AGGIA65_FY
# 1147    729 -1.585846e+11  AGGIA15_CY
# 1148    730 -1.585847e+11  AGGIA25_CY
# 1149    732 -1.680418e+11  AGGIA45_CY
# 1150    733 -1.680437e+11  AGGIA55_CY
# 1151    728 -1.728170e+11  AGGHINC_FY
# 1152    726 -1.728173e+11   AGGINC_FY
# 1153    727 -1.728177e+11  AGGHINC_CY
# 1154    731 -1.735612e+11  AGGIA35_CY
# 1155    720 -1.901369e+11  HAGEBASECY
# 1156    721 -1.901374e+11  HSPMBASECY
# 1157    718 -1.901822e+11  MLTMBASECY
# 1158    719 -1.901835e+11  MLTFBASECY
# 1159    724 -1.939082e+11  OCCBASE_CY
# 1160    725 -1.939088e+11   AGGINC_CY
# 1161    722 -1.939487e+11  HSPFBASECY
# 1162    723 -1.939518e+11  INDBASE_CY
#
# [1163 rows x 3 columns]
